# %% [markdown]
# <a href="https://colab.research.google.com/github/FONDECYTACC/nDP/blob/main/data_exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/content/drive/MyDrive/Alvacast/SISTRAT 2022 (github)/11.RData
/content/drive/MyDrive/Alvacast/SISTRAT 2022 (github)/from math import radians.py
